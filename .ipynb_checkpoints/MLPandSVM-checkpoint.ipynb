# %%
import scipy.io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
random.seed(42)

mat = scipy.io.loadmat('dados_treinamento.mat')
data = pd.DataFrame(np.hstack((mat['X'], mat['y'])))

# %%
data_class_1 = data.loc[data[2] == 1] # Dataframe dos padrões da classe 1
data_class_0 = data.loc[data[2] == -1] # Dataframe dos padrões da classe -1
print('Shape:',data.shape)
data.head()
# Out:
# Shape: (1000, 3)
#           0         1    2
# 0  0.595256  0.000000  1.0
# 1  1.006073  0.595256  1.0
# 2  0.483975  1.006073 -1.0
# 3 -0.394707  0.483975  1.0
# 4  1.166833 -0.394707  1.0

# %%
plt.figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.plot(data[0], data[1], 'o', alpha=.6)
plt.plot(data_class_1[0], data_class_1[1], 'bo', alpha=.6)
plt.plot(data_class_0[0], data_class_0[1], 'ro', alpha=.6)
plt.legend((-1,1))
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()

# %%
def split_data(data, split, X_training = [], X_test = []):
    for x in range(len(data)):
        if random.random() < split:
            X_training.append(data[x])
        else:
            X_test.append(data[x])

# %%
df = data.values.tolist()
X_training = []
X_test = []
split_data(df, 0.7, X_training, X_test) # Holdout 70%

data_train = pd.DataFrame(X_training)
data_test = pd.DataFrame(X_test)
print(data_train.shape)
data_train_labels = data_train[2]
data_test_labels = data_test[2]
data_train = data_train.drop(2, axis=1)
data_test = data_test.drop(2, axis=1)
# Out:
# (692, 3)

# %%
from sklearn.neural_network import MLPClassifier

classifier = MLPClassifier(solver="sgd", activation="tanh", max_iter=800, verbose=False)

# %%
classifier.hidden_layer_sizes = (1,)
classifier.fit(data_train, data_train_labels)
# Out:
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(1,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=800, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='sgd', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
fig, ax = plt.subplots(figsize=(10,6), dpi=80, facecolor='w', edgecolor='k')
for alfa in [0.001, 0.01, 0.1, 1]:
    classifier.learning_rate_init = alfa
    classifier.fit(data_train, data_train_labels)
    ax.semilogy(classifier.loss_curve_)
    
plt.legend(('alfa = 0.001', 0.01, .1, 1))
plt.grid(True)
plt.grid(True, linestyle='--', linewidth=0.8)
plt.show()

# %%
from sklearn.metrics import log_loss
classifier.learning_rate_init = 0.1
#classifier2 = MLPClassifier(solver="sgd", activation="tanh", max_iter=1000, verbose=False, learning_rate_init=1)
train_errors, val_errors = [], []
fig, ax = plt.subplots(figsize=(10,6), dpi=80, facecolor='w', edgecolor='k')
for m in range(5, len(data_train)):
    classifier.fit(data_train[:m], data_train_labels[:m])
    y_train_predict = classifier.predict_proba(data_train[:m])
    y_val_predict = classifier.predict_proba(data_test)
    
    train_errors.append(log_loss(data_train_labels[:m], y_train_predict))
    val_errors.append(log_loss(data_test_labels, y_val_predict))
plt.semilogy(train_errors, "b-", linewidth=0.8)
plt.semilogy(val_errors, "r-", linewidth=1)
plt.axis([0, 800, 10**(-1), 10**(1)])
plt.show()

# %%
y_train_predict
# Out:
# array([[0.27874313, 0.72125687],
#        [0.2663291 , 0.7336709 ],
#        [0.50175193, 0.49824807],
#        ...,
#        [0.23010246, 0.76989754],
#        [0.14635985, 0.85364015],
#        [0.2593499 , 0.7406501 ]])

# %%
y_val_predict
# Out:
# array([[0.17468959, 0.82531041],
#        [0.92213997, 0.07786003],
#        [0.17146842, 0.82853158],
#        [0.2857374 , 0.7142626 ],
#        [0.25749507, 0.74250493],
#        [0.57892502, 0.42107498],
#        [0.35254427, 0.64745573],
#        [0.29923814, 0.70076186],
#        [0.44510725, 0.55489275],
#        [0.16060939, 0.83939061],
#        [0.42541622, 0.57458378],
#        [0.92395926, 0.07604074],
#        [0.80877089, 0.19122911],
#        [0.65823735, 0.34176265],
#        [0.37647449, 0.62352551],
#        [0.29499792, 0.70500208],
#        [0.28505087, 0.71494913],
#        [0.74855223, 0.25144777],
#        [0.21639641, 0.78360359],
#        [0.80467257, 0.19532743],
#        [0.61585736, 0.38414264],
#        [0.18503883, 0.81496117],
#        [0.21476623, 0.78523377],
#        [0.28045432, 0.71954568],
#        [0.81846713, 0.18153287],
#        [0.77005909, 0.22994091],
#        [0.33073822, 0.66926178],
#        [0.47863598, 0.52136402],
#        [0.94405062, 0.05594938],
#        [0.81019549, 0.18980451],
#        [0.18319066, 0.81680934],
#        [0.27511665, 0.72488335],
#        [0.22703235, 0.77296765],
#        [0.3544691 , 0.6455309 ],
#        [0.45921965, 0.54078035],
#        [0.4780352 , 0.5219648 ],
#        [0.58082775, 0.41917225],
#        [0.49626246, 0.50373754],
#        [0.60648035, 0.39351965],
#        [0.16485818, 0.83514182],
#        [0.72106317, 0.27893683],
#        [0.56619743, 0.43380257],
#        [0.30411818, 0.69588182],
#        [0.31600645, 0.68399355],
#        [0.14640785, 0.85359215],
#        [0.24413681, 0.75586319],
#        [0.40676999, 0.59323001],
#        [0.17916031, 0.82083969],
#        [0.26296941, 0.73703059],
#        [0.24064062, 0.75935938],
#        [0.4098761 , 0.5901239 ],
#        [0.52355465, 0.47644535],
#        [0.23293272, 0.76706728],
#        [0.5395308 , 0.4604692 ],
#        [0.76281029, 0.23718971],
#        [0.15888743, 0.84111257],
#        [0.6688316 , 0.3311684 ],
#        [0.40564886, 0.59435114],
#        [0.7634095 , 0.2365905 ],
#        [0.58636247, 0.41363753],
#        [0.71864846, 0.28135154],
#        [0.55107972, 0.44892028],
#        [0.4726558 , 0.5273442 ],
#        [0.56620963, 0.43379037],
#        [0.39416137, 0.60583863],
#        [0.43112501, 0.56887499],
#        [0.57693913, 0.42306087],
#        [0.33111226, 0.66888774],
#        [0.37439357, 0.62560643],
#        [0.24884226, 0.75115774],
#        [0.81814689, 0.18185311],
#        [0.37628652, 0.62371348],
#        [0.9130969 , 0.0869031 ],
#        [0.21158822, 0.78841178],
#        [0.17551252, 0.82448748],
#        [0.65145581, 0.34854419],
#        [0.31585001, 0.68414999],
#        [0.2233316 , 0.7766684 ],
#        [0.48213821, 0.51786179],
#        [0.35654766, 0.64345234],
#        [0.39884691, 0.60115309],
#        [0.78841942, 0.21158058],
#        [0.21671946, 0.78328054],
#        [0.69551066, 0.30448934],
#        [0.81792525, 0.18207475],
#        [0.22811937, 0.77188063],
#        [0.83360447, 0.16639553],
#        [0.49482539, 0.50517461],
#        [0.74393671, 0.25606329],
#        [0.18498735, 0.81501265],
#        [0.20361735, 0.79638265],
#        [0.29484129, 0.70515871],
#        [0.27714755, 0.72285245],
#        [0.22051383, 0.77948617],
#        [0.88379505, 0.11620495],
#        [0.18234323, 0.81765677],
#        [0.46241907, 0.53758093],
#        [0.92625006, 0.07374994],
#        [0.44120652, 0.55879348],
#        [0.33111821, 0.66888179],
#        [0.1895726 , 0.8104274 ],
#        [0.91299315, 0.08700685],
#        [0.78394689, 0.21605311],
#        [0.36686781, 0.63313219],
#        [0.26170958, 0.73829042],
#        [0.79352489, 0.20647511],
#        [0.60651416, 0.39348584],
#        [0.76134232, 0.23865768],
#        [0.21528538, 0.78471462],
#        [0.3932453 , 0.6067547 ],
#        [0.56974887, 0.43025113],
#        [0.31504375, 0.68495625],
#        [0.32560957, 0.67439043],
#        [0.54241478, 0.45758522],
#        [0.38177861, 0.61822139],
#        [0.71131517, 0.28868483],
#        [0.8951738 , 0.1048262 ],
#        [0.8572251 , 0.1427749 ],
#        [0.78499905, 0.21500095],
#        [0.38807106, 0.61192894],
#        [0.23306089, 0.76693911],
#        [0.7646868 , 0.2353132 ],
#        [0.17407297, 0.82592703],
#        [0.50127583, 0.49872417],
#        [0.41923575, 0.58076425],
#        [0.71529454, 0.28470546],
#        [0.94457233, 0.05542767],
#        [0.19117748, 0.80882252],
#        [0.31271719, 0.68728281],
#        [0.71551361, 0.28448639],
#        [0.20452091, 0.79547909],
#        [0.52155659, 0.47844341],
#        [0.17330186, 0.82669814],
#        [0.27444885, 0.72555115],
#        [0.55084557, 0.44915443],
#        [0.20491917, 0.79508083],
#        [0.44642218, 0.55357782],
#        [0.39468197, 0.60531803],
#        [0.32121086, 0.67878914],
#        [0.33871024, 0.66128976],
#        [0.43356306, 0.56643694],
#        [0.8848112 , 0.1151888 ],
#        [0.74712083, 0.25287917],
#        [0.17957034, 0.82042966],
#        [0.48750993, 0.51249007],
#        [0.30737759, 0.69262241],
#        [0.91270014, 0.08729986],
#        [0.62941563, 0.37058437],
#        [0.15030389, 0.84969611],
#        [0.30137747, 0.69862253],
#        [0.54211819, 0.45788181],
#        [0.72870831, 0.27129169],
#        [0.59836316, 0.40163684],
#        [0.34798301, 0.65201699],
#        [0.38958151, 0.61041849],
#        [0.22511403, 0.77488597],
#        [0.20976432, 0.79023568],
#        [0.26794534, 0.73205466],
#        [0.274844  , 0.725156  ],
#        [0.35291973, 0.64708027],
#        [0.67422899, 0.32577101],
#        [0.27747348, 0.72252652],
#        [0.5007288 , 0.4992712 ],
#        [0.72699817, 0.27300183],
#        [0.27561699, 0.72438301],
#        [0.80383916, 0.19616084],
#        [0.54013477, 0.45986523],
#        [0.60714118, 0.39285882],
#        [0.65114302, 0.34885698],
#        [0.52267048, 0.47732952],
#        [0.39124361, 0.60875639],
#        [0.62226849, 0.37773151],
#        [0.51673694, 0.48326306],
#        [0.3731567 , 0.6268433 ],
#        [0.23928493, 0.76071507],
#        [0.50528616, 0.49471384],
#        [0.19599626, 0.80400374],
#        [0.81917747, 0.18082253],
#        [0.67055106, 0.32944894],
#        [0.92064702, 0.07935298],
#        [0.61094035, 0.38905965],
#        [0.20481169, 0.79518831],
#        [0.28294731, 0.71705269],
#        [0.31025352, 0.68974648],
#        [0.22233689, 0.77766311],
#        [0.21362369, 0.78637631],
#        [0.70074674, 0.29925326],
#        [0.4248834 , 0.5751166 ],
#        [0.26152633, 0.73847367],
#        [0.31053506, 0.68946494],
#        [0.92423432, 0.07576568],
#        [0.28295744, 0.71704256],
#        [0.68971749, 0.31028251],
#        [0.6299429 , 0.3700571 ],
#        [0.26492148, 0.73507852],
#        [0.20849975, 0.79150025],
#        [0.41491111, 0.58508889],
#        [0.29027654, 0.70972346],
#        [0.8059388 , 0.1940612 ],
#        [0.49683537, 0.50316463],
#        [0.17312784, 0.82687216],
#        [0.55555489, 0.44444511],
#        [0.76076722, 0.23923278],
#        [0.35342711, 0.64657289],
#        [0.22689821, 0.77310179],
#        [0.51984731, 0.48015269],
#        [0.2524478 , 0.7475522 ],
#        [0.96352744, 0.03647256],
#        [0.63778372, 0.36221628],
#        [0.31191967, 0.68808033],
#        [0.17393754, 0.82606246],
#        [0.28691717, 0.71308283],
#        [0.1647393 , 0.8352607 ],
#        [0.2169243 , 0.7830757 ],
#        [0.18662965, 0.81337035],
#        [0.23428122, 0.76571878],
#        [0.67560044, 0.32439956],
#        [0.41972994, 0.58027006],
#        [0.28545356, 0.71454644],
#        [0.60559059, 0.39440941],
#        [0.8747343 , 0.1252657 ],
#        [0.3072083 , 0.6927917 ],
#        [0.2370324 , 0.7629676 ],
#        [0.21496143, 0.78503857],
#        [0.81903699, 0.18096301],
#        [0.27246943, 0.72753057],
#        [0.18815855, 0.81184145],
#        [0.22062987, 0.77937013],
#        [0.35206818, 0.64793182],
#        [0.3732781 , 0.6267219 ],
#        [0.2516299 , 0.7483701 ],
#        [0.31977591, 0.68022409],
#        [0.9268172 , 0.0731828 ],
#        [0.22390267, 0.77609733],
#        [0.15559214, 0.84440786],
#        [0.82210371, 0.17789629],
#        [0.25582821, 0.74417179],
#        [0.42926253, 0.57073747],
#        [0.23735417, 0.76264583],
#        [0.54622532, 0.45377468],
#        [0.17098428, 0.82901572],
#        [0.74787228, 0.25212772],
#        [0.37278364, 0.62721636],
#        [0.57015805, 0.42984195],
#        [0.33242255, 0.66757745],
#        [0.80701843, 0.19298157],
#        [0.23731011, 0.76268989],
#        [0.93662428, 0.06337572],
#        [0.54981686, 0.45018314],
#        [0.17100135, 0.82899865],
#        [0.42561521, 0.57438479],
#        [0.93425575, 0.06574425],
#        [0.44619422, 0.55380578],
#        [0.75654344, 0.24345656],
#        [0.72659665, 0.27340335],
#        [0.92808085, 0.07191915],
#        [0.33709995, 0.66290005],
#        [0.35875216, 0.64124784],
#        [0.50886056, 0.49113944],
#        [0.85552257, 0.14447743],
#        [0.68567461, 0.31432539],
#        [0.44165551, 0.55834449],
#        [0.91857052, 0.08142948],
#        [0.65872226, 0.34127774],
#        [0.64064161, 0.35935839],
#        [0.28760295, 0.71239705],
#        [0.90934244, 0.09065756],
#        [0.50934675, 0.49065325],
#        [0.17665412, 0.82334588],
#        [0.56023243, 0.43976757],
#        [0.46575308, 0.53424692],
#        [0.67773052, 0.32226948],
#        [0.82010601, 0.17989399],
#        [0.16464076, 0.83535924],
#        [0.86644482, 0.13355518],
#        [0.17789771, 0.82210229],
#        [0.57252543, 0.42747457],
#        [0.3834041 , 0.6165959 ],
#        [0.73918336, 0.26081664],
#        [0.74218073, 0.25781927],
#        [0.35571864, 0.64428136],
#        [0.21907583, 0.78092417],
#        [0.46654595, 0.53345405],
#        [0.80488444, 0.19511556],
#        [0.20034252, 0.79965748],
#        [0.57081446, 0.42918554],
#        [0.33054856, 0.66945144],
#        [0.44593884, 0.55406116],
#        [0.63613406, 0.36386594],
#        [0.37227402, 0.62772598],
#        [0.86769788, 0.13230212],
#        [0.67981001, 0.32018999],
#        [0.89029382, 0.10970618],
#        [0.20222223, 0.79777777],
#        [0.47185893, 0.52814107],
#        [0.31522902, 0.68477098],
#        [0.32159578, 0.67840422],
#        [0.83766874, 0.16233126],
#        [0.33086773, 0.66913227],
#        [0.47921524, 0.52078476],
#        [0.26181711, 0.73818289],
#        [0.42529424, 0.57470576],
#        [0.1439519 , 0.8560481 ],
#        [0.41200724, 0.58799276],
#        [0.90765488, 0.09234512],
#        [0.84043407, 0.15956593],
#        [0.66579241, 0.33420759],
#        [0.31881695, 0.68118305]])

# %%
train_errors.append(log_loss(y_train_predict, data_train_labels[:300]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-ce71cefdb79e> in <module>
# ----> 1 train_errors.append(log_loss(y_train_predict, data_train_labels[:300]))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in log_loss(y_true, y_pred, eps, normalize, sample_weight, labels)
#    1762     """
#    1763     y_pred = check_array(y_pred, ensure_2d=False)
# -> 1764     check_consistent_length(y_pred, y_true, sample_weight)
#    1765
#    1766     lb = LabelBinarizer()
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [300, 691]
