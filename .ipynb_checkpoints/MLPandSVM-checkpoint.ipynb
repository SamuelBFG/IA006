# %%
import scipy.io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
random.seed(42)

mat = scipy.io.loadmat('dados_treinamento.mat')
data = pd.DataFrame(np.hstack((mat['X'], mat['y'])))

# %%
data_class_1 = data.loc[data[2] == 1] # Dataframe dos padrões da classe 1
data_class_0 = data.loc[data[2] == -1] # Dataframe dos padrões da classe -1
print('Shape:',data.shape)
data.head()
# Out:
# Shape: (1000, 3)
#           0         1    2
# 0  0.595256  0.000000  1.0
# 1  1.006073  0.595256  1.0
# 2  0.483975  1.006073 -1.0
# 3 -0.394707  0.483975  1.0
# 4  1.166833 -0.394707  1.0

# %%
plt.figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.plot(data[0], data[1], 'o', alpha=.6)
plt.plot(data_class_1[0], data_class_1[1], 'bo', alpha=.6)
plt.plot(data_class_0[0], data_class_0[1], 'ro', alpha=.6)
plt.legend((-1,1))
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()

# %%
def split_data(data, split, X_training = [], X_test = []):
    for x in range(len(data)):
        if random.random() < split:
            X_training.append(data[x])
        else:
            X_test.append(data[x])

# %%
df = data.values.tolist()
X_training = []
X_test = []
split_data(df, 0.7, X_training, X_test) # Holdout 70%

data_train = pd.DataFrame(X_training)
data_test = pd.DataFrame(X_test)
print(data_train.shape)
data_train_labels = data_train[2]
data_test_labels = data_test[2]
data_train = data_train.drop(2, axis=1)
data_test = data_test.drop(2, axis=1)
# Out:
# (692, 3)

# %%
from sklearn.neural_network import MLPClassifier

classifier = MLPClassifier(solver="sgd", activation="tanh", max_iter=800, verbose=True)

# %%
classifier.hidden_layer_sizes = (1,)
classifier.fit(data_train, data_train_labels)
# Out:
# Iteration 1, loss = 0.71487302
# Iteration 2, loss = 0.62504916
# Iteration 3, loss = 0.57241031
# Iteration 4, loss = 0.57250208
# Iteration 5, loss = 0.71126824
# Iteration 6, loss = 0.58849853
# Iteration 7, loss = 0.58218201
# Iteration 8, loss = 0.58431761
# Iteration 9, loss = 0.58157560
# Iteration 10, loss = 0.58048744
# Iteration 11, loss = 0.58382236
# Iteration 12, loss = 0.58234940
# Iteration 13, loss = 0.57757733
# Iteration 14, loss = 0.57573769
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(1,), learning_rate='constant',
#        learning_rate_init=1, max_iter=800, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='sgd', tol=0.0001,
#        validation_fraction=0.1, verbose=True, warm_start=False)

# %%
classifier.loss_
# Out:
# 0.5757376942209343

# %%
fig, ax = plt.subplots(figsize=(10,6), dpi=80, facecolor='w', edgecolor='k')
for alfa in [0.001, 0.01, 0.1, 1]:
    classifier.learning_rate_init = alfa
    classifier.fit(data_train, data_train_labels)
    ax.semilogy(classifier.loss_curve_)
    
plt.legend(('alfa = 0.001', 0.01, .1, 1))
plt.grid(True)
plt.grid(True, linestyle='--', linewidth=0.8)
plt.show()
# Out:
# Iteration 1, loss = 0.73171730
# Iteration 2, loss = 0.73108649
# Iteration 3, loss = 0.73005295
# Iteration 4, loss = 0.72886399
# Iteration 5, loss = 0.72748668
# Iteration 6, loss = 0.72605099
# Iteration 7, loss = 0.72454542
# Iteration 8, loss = 0.72308997
# Iteration 9, loss = 0.72160935
# Iteration 10, loss = 0.72011777
# Iteration 11, loss = 0.71871538
# Iteration 12, loss = 0.71725031
# Iteration 13, loss = 0.71588934
# Iteration 14, loss = 0.71450729
# Iteration 15, loss = 0.71314332
# Iteration 16, loss = 0.71188748
# Iteration 17, loss = 0.71058369
# Iteration 18, loss = 0.70933852
# Iteration 19, loss = 0.70810024
# Iteration 20, loss = 0.70685802
# Iteration 21, loss = 0.70572271
# Iteration 22, loss = 0.70451383
# Iteration 23, loss = 0.70338281
# Iteration 24, loss = 0.70231920
# Iteration 25, loss = 0.70114744
# Iteration 26, loss = 0.70008882
# Iteration 27, loss = 0.69901647
# Iteration 28, loss = 0.69800145
# Iteration 29, loss = 0.69685999
# Iteration 30, loss = 0.69584669
# Iteration 31, loss = 0.69487532
# Iteration 32, loss = 0.69385543
# Iteration 33, loss = 0.69292401
# Iteration 34, loss = 0.69199976
# Iteration 35, loss = 0.69113047
# Iteration 36, loss = 0.69019540
# Iteration 37, loss = 0.68936841
# Iteration 38, loss = 0.68849868
# Iteration 39, loss = 0.68764475
# Iteration 40, loss = 0.68685916
# Iteration 41, loss = 0.68604882
# Iteration 42, loss = 0.68521512
# Iteration 43, loss = 0.68440963
# Iteration 44, loss = 0.68362815
# Iteration 45, loss = 0.68284709
# Iteration 46, loss = 0.68210812
# Iteration 47, loss = 0.68133069
# Iteration 48, loss = 0.68059160
# Iteration 49, loss = 0.67984309
# Iteration 50, loss = 0.67912192
# Iteration 51, loss = 0.67844551
# Iteration 52, loss = 0.67772513
# Iteration 53, loss = 0.67704681
# Iteration 54, loss = 0.67632578
# Iteration 55, loss = 0.67572067
# Iteration 56, loss = 0.67501118
# Iteration 57, loss = 0.67439632
# Iteration 58, loss = 0.67375140
# Iteration 59, loss = 0.67314279
# Iteration 60, loss = 0.67252426
# Iteration 61, loss = 0.67190590
# Iteration 62, loss = 0.67135069
# Iteration 63, loss = 0.67071625
# Iteration 64, loss = 0.67014069
# Iteration 65, loss = 0.66955248
# Iteration 66, loss = 0.66894756
# Iteration 67, loss = 0.66837364
# Iteration 68, loss = 0.66782085
# Iteration 69, loss = 0.66727807
# Iteration 70, loss = 0.66670788
# Iteration 71, loss = 0.66615113
# Iteration 72, loss = 0.66564186
# Iteration 73, loss = 0.66510334
# Iteration 74, loss = 0.66461591
# Iteration 75, loss = 0.66411507
# Iteration 76, loss = 0.66358795
# Iteration 77, loss = 0.66307980
# Iteration 78, loss = 0.66256055
# Iteration 79, loss = 0.66208120
# Iteration 80, loss = 0.66161389
# Iteration 81, loss = 0.66109288
# Iteration 82, loss = 0.66062853
# Iteration 83, loss = 0.66013283
# Iteration 84, loss = 0.65964551
# Iteration 85, loss = 0.65915521
# Iteration 86, loss = 0.65866623
# Iteration 87, loss = 0.65819980
# Iteration 88, loss = 0.65772887
# Iteration 89, loss = 0.65724987
# Iteration 90, loss = 0.65680841
# Iteration 91, loss = 0.65632878
# Iteration 92, loss = 0.65587289
# Iteration 93, loss = 0.65541927
# Iteration 94, loss = 0.65495827
# Iteration 95, loss = 0.65451013
# Iteration 96, loss = 0.65409351
# Iteration 97, loss = 0.65363753
# Iteration 98, loss = 0.65322252
# Iteration 99, loss = 0.65281767
# Iteration 100, loss = 0.65237766
# Iteration 101, loss = 0.65194362
# Iteration 102, loss = 0.65151923
# Iteration 103, loss = 0.65112495
# Iteration 104, loss = 0.65069294
# Iteration 105, loss = 0.65026419
# Iteration 106, loss = 0.64984918
# Iteration 107, loss = 0.64943006
# Iteration 108, loss = 0.64903089
# Iteration 109, loss = 0.64859222
# Iteration 110, loss = 0.64821315
# Iteration 111, loss = 0.64779340
# Iteration 112, loss = 0.64740042
# Iteration 113, loss = 0.64700112
# Iteration 114, loss = 0.64659346
# Iteration 115, loss = 0.64620039
# Iteration 116, loss = 0.64582911
# Iteration 117, loss = 0.64542203
# Iteration 118, loss = 0.64499774
# Iteration 119, loss = 0.64459766
# Iteration 120, loss = 0.64420220
# Iteration 121, loss = 0.64377496
# Iteration 122, loss = 0.64338008
# Iteration 123, loss = 0.64298653
# Iteration 124, loss = 0.64257159
# Iteration 125, loss = 0.64216882
# Iteration 126, loss = 0.64175619
# Iteration 127, loss = 0.64135177
# Iteration 128, loss = 0.64095536
# Iteration 129, loss = 0.64056196
# Iteration 130, loss = 0.64013959
# Iteration 131, loss = 0.63974599
# Iteration 132, loss = 0.63932257
# Iteration 133, loss = 0.63892837
# Iteration 134, loss = 0.63853836
# Iteration 135, loss = 0.63813377
# Iteration 136, loss = 0.63774416
# Iteration 137, loss = 0.63733334
# Iteration 138, loss = 0.63695364
# Iteration 139, loss = 0.63654702
# Iteration 140, loss = 0.63615950
# Iteration 141, loss = 0.63573972
# Iteration 142, loss = 0.63536675
# Iteration 143, loss = 0.63496585
# Iteration 144, loss = 0.63455577
# Iteration 145, loss = 0.63417162
# Iteration 146, loss = 0.63377138
# Iteration 147, loss = 0.63335419
# Iteration 148, loss = 0.63297299
# Iteration 149, loss = 0.63259314
# Iteration 150, loss = 0.63219234
# Iteration 151, loss = 0.63179798
# Iteration 152, loss = 0.63139885
# Iteration 153, loss = 0.63102434
# Iteration 154, loss = 0.63062108
# Iteration 155, loss = 0.63022168
# Iteration 156, loss = 0.62982887
# Iteration 157, loss = 0.62944686
# Iteration 158, loss = 0.62904662
# Iteration 159, loss = 0.62863960
# Iteration 160, loss = 0.62826120
# Iteration 161, loss = 0.62785651
# Iteration 162, loss = 0.62745992
# Iteration 163, loss = 0.62705264
# Iteration 164, loss = 0.62669742
# Iteration 165, loss = 0.62625889
# Iteration 166, loss = 0.62588861
# Iteration 167, loss = 0.62549786
# Iteration 168, loss = 0.62509776
# Iteration 169, loss = 0.62471547
# Iteration 170, loss = 0.62432599
# Iteration 171, loss = 0.62392412
# Iteration 172, loss = 0.62355886
# Iteration 173, loss = 0.62316660
# Iteration 174, loss = 0.62276391
# Iteration 175, loss = 0.62238468
# Iteration 176, loss = 0.62201626
# Iteration 177, loss = 0.62161544
# Iteration 178, loss = 0.62125707
# Iteration 179, loss = 0.62087071
# Iteration 180, loss = 0.62050780
# Iteration 181, loss = 0.62011604
# Iteration 182, loss = 0.61972217
# Iteration 183, loss = 0.61931842
# Iteration 184, loss = 0.61893739
# Iteration 185, loss = 0.61855863
# Iteration 186, loss = 0.61816876
# Iteration 187, loss = 0.61778663
# Iteration 188, loss = 0.61740875
# Iteration 189, loss = 0.61704264
# Iteration 190, loss = 0.61666609
# Iteration 191, loss = 0.61626635
# Iteration 192, loss = 0.61590940
# Iteration 193, loss = 0.61551475
# Iteration 194, loss = 0.61514070
# Iteration 195, loss = 0.61476828
# Iteration 196, loss = 0.61438583
# Iteration 197, loss = 0.61404813
# Iteration 198, loss = 0.61365797
# Iteration 199, loss = 0.61330528
# Iteration 200, loss = 0.61293225
# Iteration 201, loss = 0.61256704
# Iteration 202, loss = 0.61219652
# Iteration 203, loss = 0.61182556
# Iteration 204, loss = 0.61147054
# Iteration 205, loss = 0.61107176
# Iteration 206, loss = 0.61073343
# Iteration 207, loss = 0.61037133
# Iteration 208, loss = 0.61001497
# Iteration 209, loss = 0.60967803
# Iteration 210, loss = 0.60929588
# Iteration 211, loss = 0.60894134
# Iteration 212, loss = 0.60858941
# Iteration 213, loss = 0.60823133
# Iteration 214, loss = 0.60789943
# Iteration 215, loss = 0.60752880
# Iteration 216, loss = 0.60720388
# Iteration 217, loss = 0.60685836
# Iteration 218, loss = 0.60650347
# Iteration 219, loss = 0.60616957
# Iteration 220, loss = 0.60583978
# Iteration 221, loss = 0.60550363
# Iteration 222, loss = 0.60516856
# Iteration 223, loss = 0.60484150
# Iteration 224, loss = 0.60450953
# Iteration 225, loss = 0.60417434
# Iteration 226, loss = 0.60384642
# Iteration 227, loss = 0.60353195
# Iteration 228, loss = 0.60319867
# Iteration 229, loss = 0.60287070
# Iteration 230, loss = 0.60255306
# Iteration 231, loss = 0.60223651
# Iteration 232, loss = 0.60190638
# Iteration 233, loss = 0.60160687
# Iteration 234, loss = 0.60126949
# Iteration 235, loss = 0.60097416
# Iteration 236, loss = 0.60069180
# Iteration 237, loss = 0.60036591
# Iteration 238, loss = 0.60007563
# Iteration 239, loss = 0.59976573
# Iteration 240, loss = 0.59946546
# Iteration 241, loss = 0.59916616
# Iteration 242, loss = 0.59886912
# Iteration 243, loss = 0.59858661
# Iteration 244, loss = 0.59830448
# Iteration 245, loss = 0.59800343
# Iteration 246, loss = 0.59774266
# Iteration 247, loss = 0.59743745
# Iteration 248, loss = 0.59714539
# Iteration 249, loss = 0.59688142
# Iteration 250, loss = 0.59662376
# Iteration 251, loss = 0.59632427
# Iteration 252, loss = 0.59605344
# Iteration 253, loss = 0.59578595
# Iteration 254, loss = 0.59550505
# Iteration 255, loss = 0.59522732
# Iteration 256, loss = 0.59496744
# Iteration 257, loss = 0.59469870
# Iteration 258, loss = 0.59442231
# Iteration 259, loss = 0.59415460
# Iteration 260, loss = 0.59389627
# Iteration 261, loss = 0.59363580
# Iteration 262, loss = 0.59336903
# Iteration 263, loss = 0.59312188
# Iteration 264, loss = 0.59284389
# Iteration 265, loss = 0.59258427
# Iteration 266, loss = 0.59234004
# Iteration 267, loss = 0.59206069
# Iteration 268, loss = 0.59181196
# Iteration 269, loss = 0.59156369
# Iteration 270, loss = 0.59129630
# Iteration 271, loss = 0.59105009
# Iteration 272, loss = 0.59080086
# Iteration 273, loss = 0.59054454
# Iteration 274, loss = 0.59031217
# Iteration 275, loss = 0.59004526
# Iteration 276, loss = 0.58980068
# Iteration 277, loss = 0.58954013
# Iteration 278, loss = 0.58928907
# Iteration 279, loss = 0.58905003
# Iteration 280, loss = 0.58880397
# Iteration 281, loss = 0.58856075
# Iteration 282, loss = 0.58833608
# Iteration 283, loss = 0.58810676
# Iteration 284, loss = 0.58787788
# Iteration 285, loss = 0.58764222
# Iteration 286, loss = 0.58741793
# Iteration 287, loss = 0.58719934
# Iteration 288, loss = 0.58696621
# Iteration 289, loss = 0.58674095
# Iteration 290, loss = 0.58651653
# Iteration 291, loss = 0.58630875
# Iteration 292, loss = 0.58608413
# Iteration 293, loss = 0.58587107
# Iteration 294, loss = 0.58566642
# Iteration 295, loss = 0.58545143
# Iteration 296, loss = 0.58523271
# Iteration 297, loss = 0.58503504
# Iteration 298, loss = 0.58482646
# Iteration 299, loss = 0.58461665
# Iteration 300, loss = 0.58441105
# Iteration 301, loss = 0.58420550
# Iteration 302, loss = 0.58398067
# Iteration 303, loss = 0.58378711
# Iteration 304, loss = 0.58358771
# Iteration 305, loss = 0.58336744
# Iteration 306, loss = 0.58317454
# Iteration 307, loss = 0.58298087
# Iteration 308, loss = 0.58277973
# Iteration 309, loss = 0.58258730
# Iteration 310, loss = 0.58237360
# Iteration 311, loss = 0.58216184
# Iteration 312, loss = 0.58196333
# Iteration 313, loss = 0.58176842
# Iteration 314, loss = 0.58157093
# Iteration 315, loss = 0.58137102
# Iteration 316, loss = 0.58117547
# Iteration 317, loss = 0.58099011
# Iteration 318, loss = 0.58079689
# Iteration 319, loss = 0.58061402
# Iteration 320, loss = 0.58041668
# Iteration 321, loss = 0.58023960
# Iteration 322, loss = 0.58005697
# Iteration 323, loss = 0.57986813
# Iteration 324, loss = 0.57968476
# Iteration 325, loss = 0.57949841
# Iteration 326, loss = 0.57932716
# Iteration 327, loss = 0.57914471
# Iteration 328, loss = 0.57895690
# Iteration 329, loss = 0.57878601
# Iteration 330, loss = 0.57860223
# Iteration 331, loss = 0.57843231
# Iteration 332, loss = 0.57826074
# Iteration 333, loss = 0.57809796
# Iteration 334, loss = 0.57792927
# Iteration 335, loss = 0.57777263
# Iteration 336, loss = 0.57759168
# Iteration 337, loss = 0.57744564
# Iteration 338, loss = 0.57727589
# Iteration 339, loss = 0.57711242
# Iteration 340, loss = 0.57695556
# Iteration 341, loss = 0.57678643
# Iteration 342, loss = 0.57663017
# Iteration 343, loss = 0.57646121
# Iteration 344, loss = 0.57629808
# Iteration 345, loss = 0.57612502
# Iteration 346, loss = 0.57596525
# Iteration 347, loss = 0.57580835
# Iteration 348, loss = 0.57564802
# Iteration 349, loss = 0.57549047
# Iteration 350, loss = 0.57534367
# Iteration 351, loss = 0.57518762
# Iteration 352, loss = 0.57503136
# Iteration 353, loss = 0.57488360
# Iteration 354, loss = 0.57473835
# Iteration 355, loss = 0.57459836
# Iteration 356, loss = 0.57445161
# Iteration 357, loss = 0.57431769
# Iteration 358, loss = 0.57416912
# Iteration 359, loss = 0.57403915
# Iteration 360, loss = 0.57389729
# Iteration 361, loss = 0.57376419
# Iteration 362, loss = 0.57361998
# Iteration 363, loss = 0.57348414
# Iteration 364, loss = 0.57334266
# Iteration 365, loss = 0.57321073
# Iteration 366, loss = 0.57306948
# Iteration 367, loss = 0.57293080
# Iteration 368, loss = 0.57279834
# Iteration 369, loss = 0.57266163
# Iteration 370, loss = 0.57253521
# Iteration 371, loss = 0.57240120
# Iteration 372, loss = 0.57227123
# Iteration 373, loss = 0.57213942
# Iteration 374, loss = 0.57201050
# Iteration 375, loss = 0.57188004
# Iteration 376, loss = 0.57176531
# Iteration 377, loss = 0.57164948
# Iteration 378, loss = 0.57152772
# Iteration 379, loss = 0.57140528
# Iteration 380, loss = 0.57128614
# Iteration 381, loss = 0.57117630
# Iteration 382, loss = 0.57105309
# Iteration 383, loss = 0.57093690
# Iteration 384, loss = 0.57080933
# Iteration 385, loss = 0.57069527
# Iteration 386, loss = 0.57058485
# Iteration 387, loss = 0.57046133
# Iteration 388, loss = 0.57035685
# Iteration 389, loss = 0.57023538
# Iteration 390, loss = 0.57014148
# Iteration 391, loss = 0.57002056
# Iteration 392, loss = 0.56990439
# Iteration 393, loss = 0.56980172
# Iteration 394, loss = 0.56969678
# Iteration 395, loss = 0.56958575
# Iteration 396, loss = 0.56947899
# Iteration 397, loss = 0.56937964
# Iteration 398, loss = 0.56927244
# Iteration 399, loss = 0.56917844
# Iteration 400, loss = 0.56906700
# Iteration 401, loss = 0.56897139
# Iteration 402, loss = 0.56887052
# Iteration 403, loss = 0.56877837
# Iteration 404, loss = 0.56866422
# Iteration 405, loss = 0.56857681
# Iteration 406, loss = 0.56847389
# Iteration 407, loss = 0.56837257
# Iteration 408, loss = 0.56826984
# Iteration 409, loss = 0.56818115
# Iteration 410, loss = 0.56807291
# Iteration 411, loss = 0.56797601
# Iteration 412, loss = 0.56788303
# Iteration 413, loss = 0.56779970
# Iteration 414, loss = 0.56769780
# Iteration 415, loss = 0.56761273
# Iteration 416, loss = 0.56751961
# Iteration 417, loss = 0.56743310
# Iteration 418, loss = 0.56734202
# Iteration 419, loss = 0.56724692
# Iteration 420, loss = 0.56716531
# Iteration 421, loss = 0.56706618
# Iteration 422, loss = 0.56697833
# Iteration 423, loss = 0.56688813
# Iteration 424, loss = 0.56681721
# Iteration 425, loss = 0.56672605
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.05091270
# Iteration 2, loss = 1.03366296
# Iteration 3, loss = 1.00835927
# Iteration 4, loss = 0.97916138
# Iteration 5, loss = 0.94827940
# Iteration 6, loss = 0.91823666
# Iteration 7, loss = 0.89008411
# Iteration 8, loss = 0.86255356
# Iteration 9, loss = 0.83969965
# Iteration 10, loss = 0.81751026
# Iteration 11, loss = 0.79820611
# Iteration 12, loss = 0.78099960
# Iteration 13, loss = 0.76620161
# Iteration 14, loss = 0.75333897
# Iteration 15, loss = 0.74145154
# Iteration 16, loss = 0.73158672
# Iteration 17, loss = 0.72242503
# Iteration 18, loss = 0.71503523
# Iteration 19, loss = 0.70781753
# Iteration 20, loss = 0.70153330
# Iteration 21, loss = 0.69602663
# Iteration 22, loss = 0.69110339
# Iteration 23, loss = 0.68669124
# Iteration 24, loss = 0.68260085
# Iteration 25, loss = 0.67905106
# Iteration 26, loss = 0.67579718
# Iteration 27, loss = 0.67285519
# Iteration 28, loss = 0.67018314
# Iteration 29, loss = 0.66755405
# Iteration 30, loss = 0.66536082
# Iteration 31, loss = 0.66324649
# Iteration 32, loss = 0.66135130
# Iteration 33, loss = 0.65948178
# Iteration 34, loss = 0.65787055
# Iteration 35, loss = 0.65631058
# Iteration 36, loss = 0.65469123
# Iteration 37, loss = 0.65326938
# Iteration 38, loss = 0.65188893
# Iteration 39, loss = 0.65044076
# Iteration 40, loss = 0.64911772
# Iteration 41, loss = 0.64775689
# Iteration 42, loss = 0.64634425
# Iteration 43, loss = 0.64495099
# Iteration 44, loss = 0.64358166
# Iteration 45, loss = 0.64206707
# Iteration 46, loss = 0.64057822
# Iteration 47, loss = 0.63909481
# Iteration 48, loss = 0.63755176
# Iteration 49, loss = 0.63587811
# Iteration 50, loss = 0.63410040
# Iteration 51, loss = 0.63227523
# Iteration 52, loss = 0.63037100
# Iteration 53, loss = 0.62844970
# Iteration 54, loss = 0.62617450
# Iteration 55, loss = 0.62411587
# Iteration 56, loss = 0.62174802
# Iteration 57, loss = 0.61949993
# Iteration 58, loss = 0.61697268
# Iteration 59, loss = 0.61442560
# Iteration 60, loss = 0.61203164
# Iteration 61, loss = 0.60941976
# Iteration 62, loss = 0.60684229
# Iteration 63, loss = 0.60431504
# Iteration 64, loss = 0.60186918
# Iteration 65, loss = 0.59928627
# Iteration 66, loss = 0.59679787
# Iteration 67, loss = 0.59454874
# Iteration 68, loss = 0.59215791
# Iteration 69, loss = 0.58978458
# Iteration 70, loss = 0.58782682
# Iteration 71, loss = 0.58583421
# Iteration 72, loss = 0.58375085
# Iteration 73, loss = 0.58215112
# Iteration 74, loss = 0.58019539
# Iteration 75, loss = 0.57858711
# Iteration 76, loss = 0.57711110
# Iteration 77, loss = 0.57553639
# Iteration 78, loss = 0.57420855
# Iteration 79, loss = 0.57295285
# Iteration 80, loss = 0.57190067
# Iteration 81, loss = 0.57078244
# Iteration 82, loss = 0.56975730
# Iteration 83, loss = 0.56904710
# Iteration 84, loss = 0.56805534
# Iteration 85, loss = 0.56734807
# Iteration 86, loss = 0.56657931
# Iteration 87, loss = 0.56595811
# Iteration 88, loss = 0.56530509
# Iteration 89, loss = 0.56479046
# Iteration 90, loss = 0.56425896
# Iteration 91, loss = 0.56378432
# Iteration 92, loss = 0.56326598
# Iteration 93, loss = 0.56281546
# Iteration 94, loss = 0.56237411
# Iteration 95, loss = 0.56204328
# Iteration 96, loss = 0.56165563
# Iteration 97, loss = 0.56130256
# Iteration 98, loss = 0.56095966
# Iteration 99, loss = 0.56085021
# Iteration 100, loss = 0.56037279
# Iteration 101, loss = 0.56014453
# Iteration 102, loss = 0.55992394
# Iteration 103, loss = 0.55979985
# Iteration 104, loss = 0.55951516
# Iteration 105, loss = 0.55939202
# Iteration 106, loss = 0.55919473
# Iteration 107, loss = 0.55908933
# Iteration 108, loss = 0.55891813
# Iteration 109, loss = 0.55871305
# Iteration 110, loss = 0.55855517
# Iteration 111, loss = 0.55843766
# Iteration 112, loss = 0.55829862
# Iteration 113, loss = 0.55814588
# Iteration 114, loss = 0.55806699
# Iteration 115, loss = 0.55787391
# Iteration 116, loss = 0.55774907
# Iteration 117, loss = 0.55768575
# Iteration 118, loss = 0.55760130
# Iteration 119, loss = 0.55747487
# Iteration 120, loss = 0.55746298
# Iteration 121, loss = 0.55734186
# Iteration 122, loss = 0.55723036
# Iteration 123, loss = 0.55713271
# Iteration 124, loss = 0.55708055
# Iteration 125, loss = 0.55708217
# Iteration 126, loss = 0.55694286
# Iteration 127, loss = 0.55692970
# Iteration 128, loss = 0.55680346
# Iteration 129, loss = 0.55671668
# Iteration 130, loss = 0.55664270
# Iteration 131, loss = 0.55665589
# Iteration 132, loss = 0.55655413
# Iteration 133, loss = 0.55646323
# Iteration 134, loss = 0.55645890
# Iteration 135, loss = 0.55637157
# Iteration 136, loss = 0.55630743
# Iteration 137, loss = 0.55624796
# Iteration 138, loss = 0.55621732
# Iteration 139, loss = 0.55611233
# Iteration 140, loss = 0.55606411
# Iteration 141, loss = 0.55599402
# Iteration 142, loss = 0.55599524
# Iteration 143, loss = 0.55594953
# Iteration 144, loss = 0.55584591
# Iteration 145, loss = 0.55583344
# Iteration 146, loss = 0.55572694
# Iteration 147, loss = 0.55575753
# Iteration 148, loss = 0.55563072
# Iteration 149, loss = 0.55560225
# Iteration 150, loss = 0.55551666
# Iteration 151, loss = 0.55547742
# Iteration 152, loss = 0.55546527
# Iteration 153, loss = 0.55548336
# Iteration 154, loss = 0.55531129
# Iteration 155, loss = 0.55531302
# Iteration 156, loss = 0.55528260
# Iteration 157, loss = 0.55522356
# Iteration 158, loss = 0.55516794
# Iteration 159, loss = 0.55514749
# Iteration 160, loss = 0.55504454
# Iteration 161, loss = 0.55500617
# Iteration 162, loss = 0.55498457
# Iteration 163, loss = 0.55493737
# Iteration 164, loss = 0.55489443
# Iteration 165, loss = 0.55486568
# Iteration 166, loss = 0.55481240
# Iteration 167, loss = 0.55477544
# Iteration 168, loss = 0.55475783
# Iteration 169, loss = 0.55460953
# Iteration 170, loss = 0.55456857
# Iteration 171, loss = 0.55455539
# Iteration 172, loss = 0.55453144
# Iteration 173, loss = 0.55444811
# Iteration 174, loss = 0.55439950
# Iteration 175, loss = 0.55442747
# Iteration 176, loss = 0.55434125
# Iteration 177, loss = 0.55426716
# Iteration 178, loss = 0.55423774
# Iteration 179, loss = 0.55423872
# Iteration 180, loss = 0.55411966
# Iteration 181, loss = 0.55412330
# Iteration 182, loss = 0.55405289
# Iteration 183, loss = 0.55402215
# Iteration 184, loss = 0.55409161
# Iteration 185, loss = 0.55398484
# Iteration 186, loss = 0.55388822
# Iteration 187, loss = 0.55384341
# Iteration 188, loss = 0.55386052
# Iteration 189, loss = 0.55381664
# Iteration 190, loss = 0.55374273
# Iteration 191, loss = 0.55367629
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.88597738
# Iteration 2, loss = 0.73784618
# Iteration 3, loss = 0.66305898
# Iteration 4, loss = 0.66152327
# Iteration 5, loss = 0.66687257
# Iteration 6, loss = 0.65919688
# Iteration 7, loss = 0.64474952
# Iteration 8, loss = 0.63326977
# Iteration 9, loss = 0.62182243
# Iteration 10, loss = 0.60919998
# Iteration 11, loss = 0.59398206
# Iteration 12, loss = 0.58339369
# Iteration 13, loss = 0.57629975
# Iteration 14, loss = 0.57281080
# Iteration 15, loss = 0.56908673
# Iteration 16, loss = 0.56616339
# Iteration 17, loss = 0.56551303
# Iteration 18, loss = 0.56474617
# Iteration 19, loss = 0.56350839
# Iteration 20, loss = 0.56269219
# Iteration 21, loss = 0.56216379
# Iteration 22, loss = 0.56014956
# Iteration 23, loss = 0.55904425
# Iteration 24, loss = 0.55958306
# Iteration 25, loss = 0.55834304
# Iteration 26, loss = 0.55699644
# Iteration 27, loss = 0.55730252
# Iteration 28, loss = 0.55589258
# Iteration 29, loss = 0.55589972
# Iteration 30, loss = 0.55535779
# Iteration 31, loss = 0.55466975
# Iteration 32, loss = 0.55378988
# Iteration 33, loss = 0.55345156
# Iteration 34, loss = 0.55440047
# Iteration 35, loss = 0.55248456
# Iteration 36, loss = 0.55289026
# Iteration 37, loss = 0.55274238
# Iteration 38, loss = 0.55241326
# Iteration 39, loss = 0.55251521
# Iteration 40, loss = 0.55211867
# Iteration 41, loss = 0.55157597
# Iteration 42, loss = 0.55141341
# Iteration 43, loss = 0.55239140
# Iteration 44, loss = 0.55231087
# Iteration 45, loss = 0.55381077
# Iteration 46, loss = 0.55301446
# Iteration 47, loss = 0.55035453
# Iteration 48, loss = 0.55093022
# Iteration 49, loss = 0.54915711
# Iteration 50, loss = 0.55055737
# Iteration 51, loss = 0.55066174
# Iteration 52, loss = 0.55015212
# Iteration 53, loss = 0.54914965
# Iteration 54, loss = 0.54948341
# Iteration 55, loss = 0.55173590
# Iteration 56, loss = 0.54867082
# Iteration 57, loss = 0.54969929
# Iteration 58, loss = 0.54897600
# Iteration 59, loss = 0.54882709
# Iteration 60, loss = 0.54901742
# Iteration 61, loss = 0.55054684
# Iteration 62, loss = 0.54949296
# Iteration 63, loss = 0.55084002
# Iteration 64, loss = 0.54901451
# Iteration 65, loss = 0.55007881
# Iteration 66, loss = 0.54836979
# Iteration 67, loss = 0.54937875
# Iteration 68, loss = 0.55122092
# Iteration 69, loss = 0.55078112
# Iteration 70, loss = 0.54861693
# Iteration 71, loss = 0.54982584
# Iteration 72, loss = 0.54952760
# Iteration 73, loss = 0.54992502
# Iteration 74, loss = 0.54837534
# Iteration 75, loss = 0.54763949
# Iteration 76, loss = 0.55146367
# Iteration 77, loss = 0.54890537
# Iteration 78, loss = 0.54863800
# Iteration 79, loss = 0.54963910
# Iteration 80, loss = 0.54751534
# Iteration 81, loss = 0.54783303
# Iteration 82, loss = 0.54711022
# Iteration 83, loss = 0.54794127
# Iteration 84, loss = 0.54885001
# Iteration 85, loss = 0.54832146
# Iteration 86, loss = 0.54749201
# Iteration 87, loss = 0.54889189
# Iteration 88, loss = 0.54751370
# Iteration 89, loss = 0.54774161
# Iteration 90, loss = 0.54960989
# Iteration 91, loss = 0.54876362
# Iteration 92, loss = 0.54800863
# Iteration 93, loss = 0.54817277
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.70562579
# Iteration 2, loss = 0.60511846
# Iteration 3, loss = 0.57608942
# Iteration 4, loss = 0.57190564
# Iteration 5, loss = 0.55885916
# Iteration 6, loss = 0.56145584
# Iteration 7, loss = 0.55595806
# Iteration 8, loss = 0.55444274
# Iteration 9, loss = 0.54728942
# Iteration 10, loss = 0.54748257
# Iteration 11, loss = 0.53596833
# Iteration 12, loss = 0.52510013
# Iteration 13, loss = 0.52335193
# Iteration 14, loss = 0.51593002
# Iteration 15, loss = 0.51592201
# Iteration 16, loss = 0.51336924
# Iteration 17, loss = 0.51289672
# Iteration 18, loss = 0.51387795
# Iteration 19, loss = 0.51092598
# Iteration 20, loss = 0.50886737
# Iteration 21, loss = 0.50892545
# Iteration 22, loss = 0.51044226
# Iteration 23, loss = 0.50983410
# Iteration 24, loss = 0.50829906
# Iteration 25, loss = 0.50754813
# Iteration 26, loss = 0.50869608
# Iteration 27, loss = 0.50698696
# Iteration 28, loss = 0.51163323
# Iteration 29, loss = 0.50719347
# Iteration 30, loss = 0.51109575
# Iteration 31, loss = 0.50753639
# Iteration 32, loss = 0.50853515
# Iteration 33, loss = 0.50943833
# Iteration 34, loss = 0.50922602
# Iteration 35, loss = 0.50709111
# Iteration 36, loss = 0.51099624
# Iteration 37, loss = 0.50774453
# Iteration 38, loss = 0.50835654
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
from sklearn.metrics import log_loss
classifier.learning_rate_init = 0.1
#classifier2 = MLPClassifier(solver="sgd", activation="tanh", max_iter=1000, verbose=False, learning_rate_init=1)
train_errors, val_errors = [], []
fig, ax = plt.subplots(figsize=(10,6), dpi=80, facecolor='w', edgecolor='k')
for m in range(5, len(data_train)):
    classifier.fit(data_train[:m], data_train_labels[:m])
    y_train_predict = classifier.predict_proba(data_train[:m])
    y_val_predict = classifier.predict_proba(data_test)
    
    train_errors.append(log_loss(data_train_labels[:m], y_train_predict))
    val_errors.append(log_loss(data_test_labels, y_val_predict))
plt.semilogy(train_errors, "b-", linewidth=0.8)
plt.semilogy(val_errors, "r-", linewidth=1)
plt.axis([0, 800, 10**(-1), 10**(1)])
plt.show()

# %%
y_train_predict
# Out:
# array([[0.27438058, 0.72561942],
#        [0.25692859, 0.74307141],
#        [0.50870098, 0.49129902],
#        ...,
#        [0.21633641, 0.78366359],
#        [0.10607013, 0.89392987],
#        [0.24461386, 0.75538614]])

# %%
print(__doc__)
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn import datasets

# different learning rate schedules and momentum parameters
params = [{'solver': 'sgd', 'learning_rate': 'constant', 'momentum': 0,
           'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': True, 'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': 0,
           'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': .9,
           'nesterovs_momentum': True, 'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.2},
          {'solver': 'adam', 'learning_rate_init': 0.01}]

labels = ["constant learning-rate", "constant with momentum",
          "constant with Nesterov's momentum",
          "inv-scaling learning-rate", "inv-scaling with momentum",
          "inv-scaling with Nesterov's momentum", "adam"]

plot_args = [{'c': 'red', 'linestyle': '-'},
             {'c': 'green', 'linestyle': '-'},
             {'c': 'blue', 'linestyle': '-'},
             {'c': 'red', 'linestyle': '--'},
             {'c': 'green', 'linestyle': '--'},
             {'c': 'blue', 'linestyle': '--'},
             {'c': 'black', 'linestyle': '-'}]


def plot_on_dataset(X, y, ax, name):
    # for each dataset, plot learning for each learning strategy
    print("\nlearning on dataset %s" % name)
    ax.set_title(name)
    X = MinMaxScaler().fit_transform(X)
    mlps = []
    if name == "digits":
        # digits is larger but converges fairly quickly
        max_iter = 15
    else:
        max_iter = 700

    for label, param in zip(labels, params):
        print("training: %s" % label)
        mlp = MLPClassifier(verbose=0, random_state=0,
                            max_iter=max_iter, **param)
        mlp.fit(X, y)
        mlps.append(mlp)
        print("Training set score: %f" % mlp.score(X, y))
        print("Training set loss: %f" % mlp.loss_)
    for mlp, label, args in zip(mlps, labels, plot_args):
            ax.plot(mlp.loss_curve_, label=label, **args)


fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# load / generate some toy datasets
iris = datasets.load_iris()
digits = datasets.load_digits()
data_sets = [(iris.data, iris.target),
             (digits.data, digits.target),
             datasets.make_circles(noise=0.2, factor=0.5, random_state=1),
             datasets.make_moons(noise=0.3, random_state=0)]

for ax, data, name in zip(axes.ravel(), data_sets, ['iris', 'digits',
                                                    'circles', 'moons']):
    plot_on_dataset(*data, ax=ax, name=name)

fig.legend(ax.get_lines(), labels, ncol=3, loc="upper center")
plt.show()
# Out:
# Automatically created module for IPython interactive environment
#
# learning on dataset iris
# training: constant learning-rate
# Training set score: 0.980000
# Training set loss: 0.080111
# training: constant with momentum
# Training set score: 0.980000
# Training set loss: 0.049530
# training: constant with Nesterov's momentum
# Training set score: 0.980000
# Training set loss: 0.049540
# training: inv-scaling learning-rate
# Training set score: 0.360000
# Training set loss: 0.978444
# training: inv-scaling with momentum
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.886667
# Training set loss: 0.446216
# training: inv-scaling with Nesterov's momentum
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.886667
# Training set loss: 0.446731
# training: adam
# Training set score: 0.980000
# Training set loss: 0.045311
#
# learning on dataset digits
# training: constant learning-rate
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.956038
# Training set loss: 0.243802
# training: constant with momentum
# Training set score: 0.992766
# Training set loss: 0.041297
# training: constant with Nesterov's momentum
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.993879
# Training set loss: 0.042898
# training: inv-scaling learning-rate
# Training set score: 0.638843
# Training set loss: 1.855465
# training: inv-scaling with momentum
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.912632
# Training set loss: 0.290584
# training: inv-scaling with Nesterov's momentum
# Training set score: 0.909293
# Training set loss: 0.318387
# training: adam
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.991653
# Training set loss: 0.045934
#
# learning on dataset circles
# training: constant learning-rate
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.880000
# Training set loss: 0.448250
# training: constant with momentum
# Training set score: 0.940000
# Training set loss: 0.154997
# training: constant with Nesterov's momentum
# Training set score: 0.940000
# Training set loss: 0.150630
# training: inv-scaling learning-rate
# Training set score: 0.500000
# Training set loss: 0.692470
# training: inv-scaling with momentum
# Training set score: 0.500000
# Training set loss: 0.689143
# training: inv-scaling with Nesterov's momentum
# Training set score: 0.500000
# Training set loss: 0.689751
# training: adam
# Training set score: 0.940000
# Training set loss: 0.150527
#
# learning on dataset moons
# training: constant learning-rate
# Training set score: 0.850000
# Training set loss: 0.341523
# training: constant with momentum
# Training set score: 0.850000
# Training set loss: 0.336188
# training: constant with Nesterov's momentum
# Training set score: 0.850000
# Training set loss: 0.335919
# training: inv-scaling learning-rate
# Training set score: 0.500000
# Training set loss: 0.689015
# training: inv-scaling with momentum
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.830000
# Training set loss: 0.470953
# training: inv-scaling with Nesterov's momentum
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.830000
# Training set loss: 0.471296
# training: adam
# /home/samukz/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.950000
# Training set loss: 0.122215

# %%
plt.show()
