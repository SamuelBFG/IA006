# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from logistic_regression import *

# %matplotlib inline 

data = pd.read_csv('two_moons.csv')

data = data.drop("Unnamed: 0", axis=1)
print(data.shape)
data.tail()
# Out:
# (1000, 3)
#           x_1       x_2    y
# 995  1.566579 -0.024554  1.0
# 996  0.292032  1.369826  0.0
# 997  0.351323 -0.533613  1.0
# 998  0.156315  0.080978  1.0
# 999  0.514015 -0.503676  1.0

# %%
#data.sort_values(by='y', ascending=True)
data_class_1 = data.loc[data['y'] == 1] # Dataframe dos padrões da classe 1
data_class_0 = data.loc[data['y'] == 0] # Dataframe dos padrões da classe 0
print(data_class_0.head())
data_class_1.head()
# Out:
#          x_1       x_2    y
# 2  -0.245490  1.068868  0.0
# 6   0.898613  0.822658  0.0
# 7   0.052219  1.363686  0.0
# 8  -0.628466  1.141305  0.0
# 10 -1.157106  0.504670  0.0
#         x_1       x_2    y
# 0  2.064430  0.546069  1.0
# 1  1.762473 -0.062689  1.0
# 3 -0.174630  0.183882  1.0
# 4  0.452110 -0.406512  1.0
# 5  1.939612  0.430906  1.0

# %%
plt.figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(data_class_0['x_1'], data_class_0['x_2'], 'o', alpha=.6)
plt.plot(data_class_1['x_1'], data_class_1['x_2'], 'ro', alpha=.6)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()

# %%
teste = np.asarray(data.drop('y', axis=1))
teste_y = np.asarray(data['y'])
print(teste.shape)
print(teste_y.shape)
# Out:
# (1000, 2)
# (1000,)

# %%
from collections import Counter
count = Counter(teste_y)
count
# Out:
# Counter({1.0: 500, 0.0: 500})

# %%
# Compute the number of points of class C1 as N1 and class C2 as N2
N1 = count[0]
N2 = count[1]
print("# of points from class C1:",N1)
print("# of points from class C2:",N2)
# Out:
# # of points from class C1: 500
# # of points from class C2: 500

# %%
C1 = []
C1_labels = []

C2 = []
C2_labels = []

# separate inputs from class C1 and C2 in different numpy arrays
for i in range(len(teste_y)):
    y = teste_y[i]
    x = teste[i]
    if y == 0:
        C1.append(x)
        C1_labels.append(y)
    elif y == 1:
        C2.append(x)
        C2_labels.append(y)
    
C1 = np.asarray(C1)
C1_labels = np.asarray(C1_labels)
C2 = np.asarray(C2)
C2_labels = np.asarray(C2_labels)

print(C1.shape, C1_labels.shape)
# Out:
# (500, 2) (500,)

# %%
# compute the mean vector for each of the 2 classes
# compute the mean accros the Bash size dimension
m1 = np.mean(C1,axis=0)
m2 = np.mean(C2,axis=0)
print(m1, m2)
# Out:
# [-0.00174703  1.03675024] [ 1.00541181 -0.14052539]

# %%
# total within-class covariance matrix, given by (4.27)
print("Input vector shape:",C1.shape)
print("m1.shape",m1.shape)

tmp = np.subtract(C1, m1)
a = np.dot(tmp.T, tmp)

tmp = np.subtract(C2, m2)
b = np.dot(tmp.T, tmp)
SW = np.add(a,b)

print("Output:",SW)
# Out:
# Input vector shape: (500, 2)
# m1.shape (2,)
# Output: [[ 5.21783589e+02 -2.68249071e-02]
#  [-2.68249071e-02  1.19062707e+02]]

# %%
from numpy.linalg import pinv
inv_SW = pinv(SW)
s = m2 - m1
W = np.dot(inv_SW, s) # 
print(W)
# Out:
# [ 0.00192971 -0.00988743]

# %%
print("Input shape:",teste.shape)
y_hat = np.dot(teste,W)
print(y_hat.shape)
#y_hat
# Out:
# Input shape: (1000, 2)
# (1000,)

# %%
tot = 0
for m in [m1,m2]:
    tot += np.dot(np.squeeze(W), m)
    print(tot)
    

w0 = 0.5 * tot
#w0 = 0.2
print("Optimal threshold:",w0)
# Out:
# -0.01025416393662476
# -0.006924571153295344
# Optimal threshold: -0.003462285576647672

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

clf = LinearDiscriminantAnalysis()
clf.fit(teste, teste_y)
print("Accuracy:",clf.score(teste,teste_y))
# Out:
# Accuracy: 0.951

# %%
data.tail()
# Out:
#           x_1       x_2    y
# 995  1.566579 -0.024554  1.0
# 996  0.292032  1.369826  0.0
# 997  0.351323 -0.533613  1.0
# 998  0.156315  0.080978  1.0
# 999  0.514015 -0.503676  1.0

# %%
#W =np.subtract(m2,m1)
#print("Weights:",W)
float(W[0])
# Out:
# 0.0019297149788361032

# %%
fig, ax = plt.subplots(figsize=(10,8))
colors=['red','blue']
for point, pred in zip(teste,teste_y):
    plt.scatter(point[0],point[1], color=colors[int(pred)], alpha=0.4)
    proj = np.dot(point,W)/np.dot(W,W) * W
    y = np.dot(point,W)
    ax.scatter(proj[0],proj[1],color=colors[int(pred)])

    
ax.scatter(m1[0],m1[1],color='black',s=100,marker="X")
ax.scatter(m2[0],m2[1],color='black',s=100,marker="X")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.show()

# %%
yA = np.squeeze(np.dot(C1,np.expand_dims(W,1)))
yB = np.squeeze(np.dot(C2,np.expand_dims(W,1)))

#np.random.seed(0)

n_bins = 15

fig, axes = plt.subplots(nrows=1, ncols=1)

colors = ['red', 'blue']
axes.hist([yA,yB], n_bins, density=1, color=colors, histtype='bar', stacked=True)
axes.set_title('Fisher\'s Discriminant Histogram')

plt.show()

# %%
v_recalls = []
fp_tx = []
v_acc = []
f1_score = []


threshold = np.linspace(-0.05,0.05,100)

for w0 in threshold:
    predictions = []
    true_positives = 0
    false_positives = 0
    true_negatives = 0
    false_negatives = 0

    for pred in y_hat:
        if pred < w0:
            predictions.append(0)
        else:
            predictions.append(1)

    for pred, i in zip(predictions,teste_y):
        if pred == 0:
            if pred == i:
                true_negatives +=1
            else:
                false_negatives +=1
        else:
            if pred == i:
                true_positives +=1
            else:
                false_positives +=1

    # Acurácia:
    acc = (true_positives + true_negatives) / len(teste_y)

    # Precisão:
    try:
        precision = true_positives / (true_positives + false_positives)
    except ZeroDivisionError:
        precision = 0

    # Taxa de falso positivo:
    FP_tx = false_positives / (true_negatives + false_positives)

    # RECALL: Proporção de amostras da classe positiva corretamente classificadas:
    recall = true_positives / (true_positives + false_negatives)
    
    # F1-Score:
    try:
        f1 = (2*recall*precision)/(recall + precision)
    except ZeroDivisionError:
        f1 = 0
    
    print("#"*10)
    print("Threshold:", w0)
    print("Accurácia:", acc)
    print("Precisão:", precision)
    print("Recall:", recall)
    print("F1-medida:", f1)
    v_recalls.append(recall)
    fp_tx.append(FP_tx)
    v_acc.append(acc)
    f1_score.append(f1)
# Out:
# ##########
# Threshold: -0.05
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.04898989898989899
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.04797979797979798
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.046969696969696974
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.045959595959595964
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.044949494949494954
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.043939393939393945
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.04292929292929293
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.041919191919191925
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.04090909090909091
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.039898989898989906
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.03888888888888889
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.03787878787878788
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.03686868686868687
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.03585858585858586
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.03484848484848485
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.03383838383838384
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.03282828282828283
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.03181818181818182
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.030808080808080812
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.029797979797979803
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.02878787878787879
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.02777777777777778
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.02676767676767677
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.02575757575757576
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.02474747474747475
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.02373737373737374
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.02272727272727273
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.021717171717171718
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.02070707070707071
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.0196969696969697
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.01868686868686869
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.01767676767676768
# Accurácia: 0.501
# Precisão: 0.5005005005005005
# Recall: 1.0
# F1-medida: 0.66711140760507
# ##########
# Threshold: -0.01666666666666667
# Accurácia: 0.504
# Precisão: 0.5020080321285141
# Recall: 1.0
# F1-medida: 0.6684491978609626
# ##########
# Threshold: -0.01565656565656566
# Accurácia: 0.514
# Precisão: 0.5070993914807302
# Recall: 1.0
# F1-medida: 0.6729475100942127
# ##########
# Threshold: -0.01464646464646465
# Accurácia: 0.544
# Precisão: 0.5230125523012552
# Recall: 1.0
# F1-medida: 0.6868131868131868
# ##########
# Threshold: -0.013636363636363641
# Accurácia: 0.602
# Precisão: 0.5567928730512249
# Recall: 1.0
# F1-medida: 0.715307582260372
# ##########
# Threshold: -0.012626262626262631
# Accurácia: 0.66
# Precisão: 0.5952380952380952
# Recall: 1.0
# F1-medida: 0.7462686567164178
# ##########
# Threshold: -0.011616161616161622
# Accurácia: 0.718
# Precisão: 0.639386189258312
# Recall: 1.0
# F1-medida: 0.7800312012480499
# ##########
# Threshold: -0.010606060606060612
# Accurácia: 0.761
# Precisão: 0.6765899864682002
# Recall: 1.0
# F1-medida: 0.8071025020177561
# ##########
# Threshold: -0.009595959595959602
# Accurácia: 0.811
# Precisão: 0.7256894049346879
# Recall: 1.0
# F1-medida: 0.8410428931875525
# ##########
# Threshold: -0.008585858585858586
# Accurácia: 0.844
# Precisão: 0.7621951219512195
# Recall: 1.0
# F1-medida: 0.8650519031141869
# ##########
# Threshold: -0.007575757575757576
# Accurácia: 0.874
# Precisão: 0.7987220447284346
# Recall: 1.0
# F1-medida: 0.8880994671403198
# ##########
# Threshold: -0.006565656565656566
# Accurácia: 0.909
# Precisão: 0.8460236886632826
# Recall: 1.0
# F1-medida: 0.916590284142988
# ##########
# Threshold: -0.005555555555555557
# Accurácia: 0.927
# Precisão: 0.8792184724689165
# Recall: 0.99
# F1-medida: 0.9313264346190029
# ##########
# Threshold: -0.004545454545454547
# Accurácia: 0.941
# Precisão: 0.9106145251396648
# Recall: 0.978
# F1-medida: 0.9431051108968178
# ##########
# Threshold: -0.0035353535353535373
# Accurácia: 0.951
# Precisão: 0.94831013916501
# Recall: 0.954
# F1-medida: 0.9511465603190429
# ##########
# Threshold: -0.0025252525252525276
# Accurácia: 0.943
# Precisão: 0.970276008492569
# Recall: 0.914
# F1-medida: 0.94129763130793
# ##########
# Threshold: -0.001515151515151518
# Accurácia: 0.926
# Precisão: 0.9797297297297297
# Recall: 0.87
# F1-medida: 0.9216101694915254
# ##########
# Threshold: -0.0005050505050505083
# Accurácia: 0.909
# Precisão: 0.9904076738609112
# Recall: 0.826
# F1-medida: 0.900763358778626
# ##########
# Threshold: 0.0005050505050505014
# Accurácia: 0.888
# Precisão: 0.9974358974358974
# Recall: 0.778
# F1-medida: 0.8741573033707866
# ##########
# Threshold: 0.001515151515151511
# Accurácia: 0.846
# Precisão: 0.9971264367816092
# Recall: 0.694
# F1-medida: 0.8183962264150942
# ##########
# Threshold: 0.0025252525252525207
# Accurácia: 0.8
# Precisão: 1.0
# Recall: 0.6
# F1-medida: 0.7499999999999999
# ##########
# Threshold: 0.0035353535353535304
# Accurácia: 0.771
# Precisão: 1.0
# Recall: 0.542
# F1-medida: 0.7029831387808042
# ##########
# Threshold: 0.00454545454545454
# Accurácia: 0.726
# Precisão: 1.0
# Recall: 0.452
# F1-medida: 0.6225895316804408
# ##########
# Threshold: 0.00555555555555555
# Accurácia: 0.668
# Precisão: 1.0
# Recall: 0.336
# F1-medida: 0.5029940119760479
# ##########
# Threshold: 0.006565656565656566
# Accurácia: 0.606
# Precisão: 1.0
# Recall: 0.212
# F1-medida: 0.34983498349834985
# ##########
# Threshold: 0.007575757575757576
# Accurácia: 0.544
# Precisão: 1.0
# Recall: 0.088
# F1-medida: 0.16176470588235292
# ##########
# Threshold: 0.008585858585858586
# Accurácia: 0.524
# Precisão: 1.0
# Recall: 0.048
# F1-medida: 0.0916030534351145
# ##########
# Threshold: 0.009595959595959595
# Accurácia: 0.504
# Precisão: 1.0
# Recall: 0.008
# F1-medida: 0.015873015873015872
# ##########
# Threshold: 0.010606060606060605
# Accurácia: 0.501
# Precisão: 1.0
# Recall: 0.002
# F1-medida: 0.003992015968063872
# ##########
# Threshold: 0.011616161616161615
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.012626262626262624
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.013636363636363627
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.014646464646464644
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.01565656565656566
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.016666666666666663
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.01767676767676768
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.018686868686868682
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.0196969696969697
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.0207070707070707
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.021717171717171718
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.02272727272727272
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.023737373737373738
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.02474747474747474
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.025757575757575757
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.02676767676767676
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.027777777777777776
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.02878787878787878
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.029797979797979796
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.0308080808080808
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.031818181818181815
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.03282828282828283
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.033838383838383834
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.03484848484848485
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.035858585858585854
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.03686868686868687
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.03787878787878787
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.03888888888888889
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.03989898989898989
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.04090909090909091
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.04191919191919191
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.04292929292929293
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.04393939393939393
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.04494949494949495
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.04595959595959595
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.04696969696969697
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.04797979797979798
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.048989898989898986
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 0.05
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0

# %%
#fig, ax = plt.subplots(figsize=(10,6))
plt.figure(1)
#plt.subplot(211)
plt.plot(fp_tx, v_recalls, 'b-')
plt.grid(True, linestyle='--', linewidth=0.8)
plt.xlabel('Taxa de Falso Positivo')
plt.gca().legend(('ROC',))
plt.ylabel('Taxa de Verdadeiro Positivo ($Recall$)')
#threshold = np.linspace(-100,50,100)
plt.figure(2)
#plt.subplot(212)
plt.plot(threshold,f1_score, 'r-')
plt.grid(True, linestyle='--', linewidth=0.8)
plt.xlabel('Threshold')
plt.ylabel('F1-Score')
plt.show()

# %%
X = data.drop('y', axis=1)
y = data['y'].values
N =  X.shape[0] # Número de amostras
n = X.shape[1] # Número de features dos padrões

l_regression = LogisticRegression()

W, w0 = l_regression.weightInitialization(n)

# Gradiente Descendente
coeff, gradient, costs = l_regression.model_predict(W, w0, X, y, 000.1, 4500)

# Predição final
w = coeff[0]
w0 = coeff[1]
print('Pesos ótimos:', w)
print('w0 (Intercepto) ótimo:', w0)

H = l_regression.sigmoid(np.dot(w,X.T)+w0)

y_hat = l_regression.predict(H, N)
# Out:
# Pesos ótimos: [[ 1.0632669  -7.15051749]]
# w0 (Intercepto) ótimo: 2.607116012339959

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

data_class_1 = data.loc[data['y'] == 1] # Dataframe dos padrões da classe 1
data_class_0 = data.loc[data['y'] == 0] # Dataframe dos padrões da classe 0
x = np.linspace(-1.5,2.5,2)
x2 = (-1/w[0][1]) * (w[0][0] * x + w0)

plt.figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(data_class_0['x_1'], data_class_0['x_2'], 'o', alpha=.6)
plt.plot(data_class_1['x_1'], data_class_1['x_2'], 'ro', alpha=.6)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.plot(x,x2, 'k--')

plt.show()

# %%
np.mean(y_hat == y.flatten()) * 100
# Out:
# 50.1

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score 

# data2 = data.copy()

# def mapFeature(X1, X2):
#     degree = 1
#     out = np.ones(X.shape[0])[:,np.newaxis]
#     for i in range(1, degree+1):
#         for j in range(i+1):
#             out = np.hstack((out, np.multiply(np.power(X1, i-j),np.power(X2, j))[:,np.newaxis]))
#     return out
# X = mapFeature(data2.iloc[:,0], data2.iloc[:,1])
# y = data2.iloc[:,-1]

model = LogisticRegression()
model.fit(X, y)
predicted_classes = model.predict(X)
accuracy = accuracy_score(y.flatten(),predicted_classes)
parameters = model.coef_

print('Parâmetros ótimos:',parameters)
print('Acurácia:',accuracy)
# Out:
# Parâmetros ótimos: [[ 1.01568896 -6.38090249]]
# Acurácia: 0.951
# C:\Users\Samuel\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
y = np.asarray(data['y'])
v_recalls = []
fp_tx = []
v_acc = []
f1_score = []
threshold = np.linspace(-1.5,1.5,100)

for w0 in threshold:
    predictions = []
    true_positives = 0
    false_positives = 0
    true_negatives = 0
    false_negatives = 0

    for pred in H[0]:
        if pred < w0:
            predictions.append(0)
        else:
            predictions.append(1)

    for pred, i in zip(predictions,y):
        if pred == 0:
            if pred == i:
                true_negatives +=1
            else:
                false_negatives +=1
        else:
            if pred == i:
                true_positives +=1
            else:
                false_positives +=1

    # Acurácia:
    acc = (true_positives + true_negatives) / len(y)

    # Precisão:
    try:
        precision = true_positives / (true_positives + false_positives)
    except ZeroDivisionError:
        precision = 0

    # Taxa de falso positivo:
    FP_tx = false_positives / (true_negatives + false_positives)

    # RECALL: Proporção de amostras da classe positiva corretamente classificadas:
    recall = true_positives / (true_positives + false_negatives)
    
    # F1-Score:
    try:
        f1 = (2*recall*precision)/(recall + precision)
    except ZeroDivisionError:
        f1 = 0
    
    print("#"*10)
    print("Threshold:", w0)
    print("Accurácia:", acc)
    print("Precisão:", precision)
    print("Recall:", recall)
    print("F1-medida:", f1)
    v_recalls.append(recall)
    fp_tx.append(FP_tx)
    v_acc.append(acc)
    f1_score.append(f1)
# Out:
# ##########
# Threshold: -1.5
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.4696969696969697
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.4393939393939394
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.4090909090909092
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.378787878787879
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.3484848484848484
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.3181818181818181
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.2878787878787878
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.2575757575757576
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.2272727272727273
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.196969696969697
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.1666666666666665
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.1363636363636362
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.106060606060606
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.0757575757575757
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.0454545454545454
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -1.0151515151515151
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.9848484848484849
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.9545454545454546
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.9242424242424242
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.8939393939393939
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.8636363636363636
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.8333333333333333
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.803030303030303
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.7727272727272727
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.7424242424242424
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.7121212121212122
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.6818181818181818
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.6515151515151515
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.6212121212121212
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.5909090909090908
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.5606060606060606
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.5303030303030303
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.5
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.4696969696969697
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.43939393939393945
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.40909090909090917
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.3787878787878787
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.3484848484848484
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.3181818181818181
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.28787878787878785
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.25757575757575757
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.2272727272727273
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.19696969696969702
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.16666666666666652
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.13636363636363624
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.10606060606060597
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.07575757575757569
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.045454545454545414
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: -0.015151515151515138
# Accurácia: 0.5
# Precisão: 0.5
# Recall: 1.0
# F1-medida: 0.6666666666666666
# ##########
# Threshold: 0.015151515151515138
# Accurácia: 0.814
# Precisão: 0.7288629737609329
# Recall: 1.0
# F1-medida: 0.8431703204047217
# ##########
# Threshold: 0.045454545454545414
# Accurácia: 0.866
# Precisão: 0.7886435331230284
# Recall: 1.0
# F1-medida: 0.8818342151675485
# ##########
# Threshold: 0.07575757575757569
# Accurácia: 0.897
# Precisão: 0.8291873963515755
# Recall: 1.0
# F1-medida: 0.9066183136899365
# ##########
# Threshold: 0.10606060606060619
# Accurácia: 0.911
# Precisão: 0.8488964346349746
# Recall: 1.0
# F1-medida: 0.9182736455463728
# ##########
# Threshold: 0.13636363636363646
# Accurácia: 0.914
# Precisão: 0.8568965517241379
# Recall: 0.994
# F1-medida: 0.9203703703703703
# ##########
# Threshold: 0.16666666666666674
# Accurácia: 0.922
# Precisão: 0.8714788732394366
# Recall: 0.99
# F1-medida: 0.9269662921348314
# ##########
# Threshold: 0.19696969696969702
# Accurácia: 0.931
# Precisão: 0.8855098389982111
# Recall: 0.99
# F1-medida: 0.934844192634561
# ##########
# Threshold: 0.2272727272727273
# Accurácia: 0.937
# Precisão: 0.896551724137931
# Recall: 0.988
# F1-medida: 0.9400570884871551
# ##########
# Threshold: 0.25757575757575757
# Accurácia: 0.941
# Precisão: 0.903107861060329
# Recall: 0.988
# F1-medida: 0.9436485195797516
# ##########
# Threshold: 0.28787878787878785
# Accurácia: 0.949
# Precisão: 0.9180633147113594
# Recall: 0.986
# F1-medida: 0.9508196721311475
# ##########
# Threshold: 0.31818181818181834
# Accurácia: 0.952
# Precisão: 0.9264150943396227
# Recall: 0.982
# F1-medida: 0.9533980582524272
# ##########
# Threshold: 0.3484848484848486
# Accurácia: 0.951
# Precisão: 0.9278937381404174
# Recall: 0.978
# F1-medida: 0.9522882181110028
# ##########
# Threshold: 0.3787878787878789
# Accurácia: 0.957
# Precisão: 0.9402697495183044
# Recall: 0.976
# F1-medida: 0.9578017664376839
# ##########
# Threshold: 0.40909090909090917
# Accurácia: 0.957
# Precisão: 0.9471624266144814
# Recall: 0.968
# F1-medida: 0.9574678536102869
# ##########
# Threshold: 0.43939393939393945
# Accurácia: 0.953
# Precisão: 0.9485148514851485
# Recall: 0.958
# F1-medida: 0.9532338308457711
# ##########
# Threshold: 0.4696969696969697
# Accurácia: 0.953
# Precisão: 0.9539078156312625
# Recall: 0.952
# F1-medida: 0.9529529529529529
# ##########
# Threshold: 0.5
# Accurácia: 0.951
# Precisão: 0.9555555555555556
# Recall: 0.946
# F1-medida: 0.9507537688442211
# ##########
# Threshold: 0.5303030303030303
# Accurácia: 0.949
# Precisão: 0.9572301425661914
# Recall: 0.94
# F1-medida: 0.9485368314833502
# ##########
# Threshold: 0.5606060606060606
# Accurácia: 0.95
# Precisão: 0.9591836734693877
# Recall: 0.94
# F1-medida: 0.9494949494949495
# ##########
# Threshold: 0.5909090909090908
# Accurácia: 0.949
# Precisão: 0.9628865979381444
# Recall: 0.934
# F1-medida: 0.9482233502538072
# ##########
# Threshold: 0.6212121212121211
# Accurácia: 0.952
# Precisão: 0.9688796680497925
# Recall: 0.934
# F1-medida: 0.9511201629327902
# ##########
# Threshold: 0.6515151515151514
# Accurácia: 0.949
# Precisão: 0.9726315789473684
# Recall: 0.924
# F1-medida: 0.9476923076923077
# ##########
# Threshold: 0.6818181818181817
# Accurácia: 0.944
# Precisão: 0.9743589743589743
# Recall: 0.912
# F1-medida: 0.9421487603305785
# ##########
# Threshold: 0.7121212121212124
# Accurácia: 0.939
# Precisão: 0.9761388286334056
# Recall: 0.9
# F1-medida: 0.9365244536940688
# ##########
# Threshold: 0.7424242424242427
# Accurácia: 0.934
# Precisão: 0.9800884955752213
# Recall: 0.886
# F1-medida: 0.930672268907563
# ##########
# Threshold: 0.7727272727272729
# Accurácia: 0.927
# Precisão: 0.9797752808988764
# Recall: 0.872
# F1-medida: 0.9227513227513227
# ##########
# Threshold: 0.8030303030303032
# Accurácia: 0.925
# Precisão: 0.9862700228832952
# Recall: 0.862
# F1-medida: 0.9199573105656351
# ##########
# Threshold: 0.8333333333333335
# Accurácia: 0.918
# Precisão: 0.9883177570093458
# Recall: 0.846
# F1-medida: 0.9116379310344827
# ##########
# Threshold: 0.8636363636363638
# Accurácia: 0.913
# Precisão: 0.9904988123515439
# Recall: 0.834
# F1-medida: 0.9055374592833875
# ##########
# Threshold: 0.893939393939394
# Accurácia: 0.903
# Precisão: 0.995085995085995
# Recall: 0.81
# F1-medida: 0.8930540242557884
# ##########
# Threshold: 0.9242424242424243
# Accurácia: 0.892
# Precisão: 0.9974619289340102
# Recall: 0.786
# F1-medida: 0.8791946308724833
# ##########
# Threshold: 0.9545454545454546
# Accurácia: 0.864
# Precisão: 0.9972677595628415
# Recall: 0.73
# F1-medida: 0.8429561200923789
# ##########
# Threshold: 0.9848484848484849
# Accurácia: 0.805
# Precisão: 1.0
# Recall: 0.61
# F1-medida: 0.7577639751552795
# ##########
# Threshold: 1.0151515151515151
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.0454545454545454
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.0757575757575757
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.106060606060606
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.1363636363636362
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.166666666666667
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.1969696969696972
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.2272727272727275
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.2575757575757578
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.287878787878788
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.3181818181818183
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.3484848484848486
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.378787878787879
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.4090909090909092
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.4393939393939394
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.4696969696969697
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0
# ##########
# Threshold: 1.5
# Accurácia: 0.5
# Precisão: 0
# Recall: 0.0
# F1-medida: 0

# %%
#fig, ax = plt.subplots(figsize=(10,6))
plt.figure(1)
#plt.subplot(211)
plt.plot(fp_tx, v_recalls, 'b-')
plt.grid(True, linestyle='--', linewidth=0.8)
plt.xlabel('Taxa de Falso Positivo')
plt.gca().legend(('ROC',))
plt.ylabel('Taxa de Verdadeiro Positivo ($Recall$)')
#threshold = np.linspace(-100,50,100)
plt.figure(2)
#plt.subplot(212)
#threshold = np.linspace(-2,2,100)
plt.plot(threshold,f1_score, 'r-')
plt.grid(True, linestyle='--', linewidth=0.8)
plt.xlabel('Threshold')
plt.ylabel('F1-Score')
plt.show()
